# %%
import pandas as pd
import numpy as np
import os
import cv2

# %%
df = pd.read_excel('painter2.xlsx')
df
# Out:
#                                              image_name image_price
# 0                                                   NaN         NaN
# 1     Jean-Jacques-MARIE-Composition-B025-Serie-B-oe...         NaN
# 2                                                   NaN         NaN
# 3                Francis-PICABIA-Le-chat-1528197291.jpg         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 2181  Harry-BARTLETT-FENNEY-rear-view-green-15582589...          60
# 2182                                                NaN         NaN
# 2183  Harry-BARTLETT-FENNEY-side-view-yellow-1558258...          50
# 2184                                                NaN         NaN
# 2185  Harry-BARTLETT-FENNEY-side-view---violet-15582...          50
#
# [2186 rows x 2 columns]

# %%
df.dropna(subset=['image_price'], inplace=True)
df
# Out:
#                                              image_name image_price
# 11             Albert-MARQUET-sans-titre-1560759132.jpg       22000
# 15                 Diana-KIROVA-Simbiosi-1531216784.jpg        1800
# 17     Diana-KIROVA-The-indipendance-day-1519509262.jpg        1800
# 35    Edouard-EVENO-Les-clowns-au-cirque--1560517679...         200
# 37         Nathalie-VAREILLE-SORBAC-ENZO-1560675497.jpg         700
# ...                                                 ...         ...
# 2177  Harry-BARTLETT-FENNEY-side-view-red-1558260362...          35
# 2179  Harry-BARTLETT-FENNEY-side-view---green-2-1558...          60
# 2181  Harry-BARTLETT-FENNEY-rear-view-green-15582589...          60
# 2183  Harry-BARTLETT-FENNEY-side-view-yellow-1558258...          50
# 2185  Harry-BARTLETT-FENNEY-side-view---violet-15582...          50
#
# [267 rows x 2 columns]

# %%
df.to_csv('painter2.csv',index=False)

# %%
df = pd.read_csv('painter2.csv')
df
# Out:
#                                             image_name image_price
# 0             Albert-MARQUET-sans-titre-1560759132.jpg       22000
# 1                 Diana-KIROVA-Simbiosi-1531216784.jpg        1800
# 2     Diana-KIROVA-The-indipendance-day-1519509262.jpg        1800
# 3    Edouard-EVENO-Les-clowns-au-cirque--1560517679...         200
# 4         Nathalie-VAREILLE-SORBAC-ENZO-1560675497.jpg         700
# ..                                                 ...         ...
# 262  Harry-BARTLETT-FENNEY-side-view-red-1558260362...          35
# 263  Harry-BARTLETT-FENNEY-side-view---green-2-1558...          60
# 264  Harry-BARTLETT-FENNEY-rear-view-green-15582589...          60
# 265  Harry-BARTLETT-FENNEY-side-view-yellow-1558258...          50
# 266  Harry-BARTLETT-FENNEY-side-view---violet-15582...          50
#
# [267 rows x 2 columns]

# %%
# Resizing Images
path = os.listdir("images")

print(path)
# Out:
# ['-ceramic-centerpiece-1588684854.jpg', '-Italian-18th-Century-Walnut-Secretary-1588598122.jpg', '-Sculpture-en-marbre-blanc--petite-fontaine--1588357261.jpg', '10cc-1587998166.jpg', '5dd6-1587999419.jpg', '629d-1587830858.jpg', '80ae-1588348091.jpg', 'A--CHOTKA-Oriental-figurative-lamp-1587150389.jpg', 'A--DE-PANAT-2-portraits-1588167052.jpg', 'A--DE-PANAT-Femme-accoudee--1588093144.jpg', 'A-R--PENCK-Selfsame-fruchte-1588171070.jpg', 'Aage-LUND-Sommerlandschaft-1585582778.jpg', 'Abdoulaye-KONATE-Composition-en-bleu-au-losange-1588843979.jpg', 'Abdoulaye-KONATE-Composition-en-rouge-touareg-seri-1588843258.jpg', 'Abdoulaye-KONATE-Violet-au-personnage-1588843342.jpg', 'Abel-BERTRAM-Nu-1576167922.jpg', 'Abelardo-BUSTAMANTE-ALVARADO-horreo-1558936916.jpg', 'Abelardo-BUSTAMANTE-ALVARADO-paisaje-con-palleiro-1496324880.jpg', 'Abelardo-BUSTAMANTE-ALVARADO-paisaje-samil-1496325142.jpg', 'Abelardo-BUSTAMANTE-ALVARADO-ria-1496325066.jpg', 'Abelardo-BUSTAMANTE-ALVARADO-rompiente-1496324978.jpg'
# ...

# %%
#Selecting all picture in the folder
path_list = []
for p in df['image_name']:
    if p.endswith('jpg'):
        path_list.append(p)
print(len(path_list))
# Out:
# 267

# %%
os.mkdir('resized')

# %%
#Defining Responses
for pat in path_list:
    new_path = os.path.join('images/',pat) #Path to file
    print(new_path)   #Showing the complete image path
    IMG_SIZE=200
    img_array=cv2.imread(new_path)
    new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
    #plt.imshow(new_array)
    cv2.imwrite('resized/'+pat,new_array)
# Out:
# images/Albert-MARQUET-sans-titre-1560759132.jpg
# images/Diana-KIROVA-Simbiosi-1531216784.jpg
# images/Diana-KIROVA-The-indipendance-day-1519509262.jpg
# images/Edouard-EVENO-Les-clowns-au-cirque--1560517679.jpg
# images/Nathalie-VAREILLE-SORBAC-ENZO-1560675497.jpg
# images/Kiyoshi-HASEGAWA-Oiseau-sur-racine-1557219747.jpg
# images/Therese-BOSC-Passage-rouge-1560584344.jpg
# images/Therese-BOSC-Noces-a-Tipasa--1560584244.jpg
# images/Therese-BOSC-Un-soleil-deja-noye-noircit-peu-a-peu-1560584129.jpg
# images/Therese-BOSC-Je-vis-le-soleil-au-fond-de-la-Mer-1560584020.jpg
# images/Therese-BOSC-A-chaque-vague-une-promesse-1560583919.jpg
# images/Therese-BOSC-Promenade-en-reverie-1560583809.jpg
# images/Therese-BOSC-Coup-de-soleil-sur-la-Falaise-bleue-1560583680.jpg
# images/Dann-AUBERT-Encore-et-encore-1560582547.jpg
# images/Dann-AUBERT-A-la-Lisiere-du-Defini-1560582309.jpg
# images/Dann-AUBERT-La-Vague-d-Or-1560582144.jpg
# images/Dann-AUBERT-Fil-de-Lumiere-1560581920.jpg
# ...

# %%
df['image_price']
# Out:
# 0      22000
# 1       1800
# 2       1800
# 3        200
# 4        700
#        ...
# 262       35
# 263       60
# 264       60
# 265       50
# 266       50
# Name: image_price, Length: 267, dtype: object

# %%
df2 = pd.read_csv('painter.csv')
df2
# Out:
#                                              image_name        image_price
# 0        Ben-JOHNSON-Versatile-Appaloosa-1589952972.jpg     1000 $ (910 €)
# 1     Jesus-Rafael-SOTO-Escritura--sintesis--1577641...              28000
# 2         Eleonora-FRANCIONI-Sorelle-n-5-1588937178.jpg                100
# 3     Christian-SATIN-Constricted-----Cat-N--6869---...               4975
# 4     Christian-SATIN-Times-are-changing-----Cat-N--...               5150
# ...                                                 ...                ...
# 5189   Lun-Gywe-U-A-Family-at-the-Shore--1586836203.jpg  16000 $ (14574 €)
# 5190             BAGYI-AUNG-SOE-Untitled-1586835675.jpg    6000 $ (5465 €)
# 5191   Thaweesak-SRITHONGDEE-Miss-Banana-1586835180.jpg  12500 $ (11386 €)
# 5192         Thaweesak-SRITHONGDEE-Berry-1586834991.jpg  15000 $ (13663 €)
# 5193  Frederique-LOMBARD-MOREL---VIBRATIONS--1586818...               2100
#
# [5194 rows x 2 columns]

# %%
frames = [df, df2]
new_df =pd.concat(frames)
new_df
# Out:
#                                              image_name        image_price
# 0              Albert-MARQUET-sans-titre-1560759132.jpg              22000
# 1                  Diana-KIROVA-Simbiosi-1531216784.jpg               1800
# 2      Diana-KIROVA-The-indipendance-day-1519509262.jpg               1800
# 3     Edouard-EVENO-Les-clowns-au-cirque--1560517679...                200
# 4          Nathalie-VAREILLE-SORBAC-ENZO-1560675497.jpg                700
# ...                                                 ...                ...
# 5189   Lun-Gywe-U-A-Family-at-the-Shore--1586836203.jpg  16000 $ (14574 €)
# 5190             BAGYI-AUNG-SOE-Untitled-1586835675.jpg    6000 $ (5465 €)
# 5191   Thaweesak-SRITHONGDEE-Miss-Banana-1586835180.jpg  12500 $ (11386 €)
# 5192         Thaweesak-SRITHONGDEE-Berry-1586834991.jpg  15000 $ (13663 €)
# 5193  Frederique-LOMBARD-MOREL---VIBRATIONS--1586818...               2100
#
# [5461 rows x 2 columns]

# %%
new_df.to_csv('painter_mod.csv', index=False)

# %%
df =pd.read_csv('painter_mod.csv')
df
# Out:
#                                              image_name        image_price
# 0              Albert-MARQUET-sans-titre-1560759132.jpg              22000
# 1                  Diana-KIROVA-Simbiosi-1531216784.jpg               1800
# 2      Diana-KIROVA-The-indipendance-day-1519509262.jpg               1800
# 3     Edouard-EVENO-Les-clowns-au-cirque--1560517679...                200
# 4          Nathalie-VAREILLE-SORBAC-ENZO-1560675497.jpg                700
# ...                                                 ...                ...
# 5456   Lun-Gywe-U-A-Family-at-the-Shore--1586836203.jpg  16000 $ (14574 €)
# 5457             BAGYI-AUNG-SOE-Untitled-1586835675.jpg    6000 $ (5465 €)
# 5458   Thaweesak-SRITHONGDEE-Miss-Banana-1586835180.jpg  12500 $ (11386 €)
# 5459         Thaweesak-SRITHONGDEE-Berry-1586834991.jpg  15000 $ (13663 €)
# 5460  Frederique-LOMBARD-MOREL---VIBRATIONS--1586818...               2100
#
# [5461 rows x 2 columns]

# %%
counter = 0
for i in df['image_price']:
    if or 'Bid' in i :
        counter+=1
print(counter)
# Out:
# 1165

# %%
df.replace('Bid','')
# Out:
#                                              image_name        image_price
# 0              Albert-MARQUET-sans-titre-1560759132.jpg              22000
# 1                  Diana-KIROVA-Simbiosi-1531216784.jpg               1800
# 2      Diana-KIROVA-The-indipendance-day-1519509262.jpg               1800
# 3     Edouard-EVENO-Les-clowns-au-cirque--1560517679...                200
# 4          Nathalie-VAREILLE-SORBAC-ENZO-1560675497.jpg                700
# ...                                                 ...                ...
# 5456   Lun-Gywe-U-A-Family-at-the-Shore--1586836203.jpg  16000 $ (14574 €)
# 5457             BAGYI-AUNG-SOE-Untitled-1586835675.jpg    6000 $ (5465 €)
# 5458   Thaweesak-SRITHONGDEE-Miss-Banana-1586835180.jpg  12500 $ (11386 €)
# 5459         Thaweesak-SRITHONGDEE-Berry-1586834991.jpg  15000 $ (13663 €)
# 5460  Frederique-LOMBARD-MOREL---VIBRATIONS--1586818...               2100
#
# [5461 rows x 2 columns]

# %%
for i in range(0,5461):
    if '(' in df['image_price'][i] :
        pos = int(df['image_price'][i].index('('))
        pos+=1
        print(pos)
        type(pos)
        val = df['image_price'][i][pos:-1]
        df['image_price'][i]=val
#         print(d)
# Out:
# 8
# 8
# 10
# 8
# 9
# 9
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 7
# 8
# 8
# 8
# 8
# 8
# 7
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 7
# 8
# 8
# 7
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 9
# 8
# 8
# 7
# 7
# 8
# 8
# 7
# 7
# 9
# 8
# 8
# 9
# 9
# 9
# 10
# 8
# 8
# 9
# 9
# 8
# 9
# 8
# 9
# 7
# 7
# 9
# 7
# 9
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 7
# 10
# 9
# 9
# 9
# 8
# 8
# 9
# 7
# 7
# 7
# 7
# 7
# 7
# 8
# 7
# 7
# 8
# 8
# 8
# 8
# 8
# 7
# 8
# 7
# 7
# 7
# 8
# 8
# 7
# 10
# 8
# 8
# 7
# 8
# 8
# 8
# 9
# 8
# 9
# 9
# 8
# 9
# 8
# 9
# 9
# 8
# 9
# 8
# 7
# 7
# 7
# 9
# 9
# 9
# 9
# 8
# 8
# 8
# 7
# 7
# 7
# 7
# 8
# 7
# 7
# 8
# 9
# 8
# 8
# 8
# 7
# 7
# 9
# 7
# 8
# 7
# 7
# 9
# 9
# 9
# 10
# 8
# 9
# 8
# 8
# 8
# 9
# 8
# 11
# 10
# 10
# 9
# 8
# 9
# 9
# 8
# 10
# 9
# 9
# 9
# 9
# 9
# 9
# 8
# 7
# 9
# 9
# 9
# 8
# 8
# 9
# 7
# 10
# 9
# 10
# 9
# 8
# 8
# 8
# 8
# 9
# 8
# 8
# 8
# 9
# 9
# 9
# 9
# 8
# 8
# 9
# 9
# 7
# 8
# 7
# 9
# 9
# 8
# 8
# 8
# 9
# 8
# 8
# 8
# 7
# 8
# 8
# 8
# 8
# 8
# 8
# 9
# ...

# %%
counter = 0
for i in df['image_price']:
    if '(' in i :
        counter+=1
print(counter)
# Out:
# 0

# %%
df.to_csv('painter_mod3.csv', index=False)

# %%
df = pd.read_csv('painter_mod3.csv')
df
# Out:
#                                              image_name  image_price
# 0              Albert-MARQUET-sans-titre-1560759132.jpg        22000
# 1                  Diana-KIROVA-Simbiosi-1531216784.jpg         1800
# 2      Diana-KIROVA-The-indipendance-day-1519509262.jpg         1800
# 3     Edouard-EVENO-Les-clowns-au-cirque--1560517679...          200
# 4          Nathalie-VAREILLE-SORBAC-ENZO-1560675497.jpg          700
# ...                                                 ...          ...
# 5456   Lun-Gywe-U-A-Family-at-the-Shore--1586836203.jpg        14574
# 5457             BAGYI-AUNG-SOE-Untitled-1586835675.jpg         5465
# 5458   Thaweesak-SRITHONGDEE-Miss-Banana-1586835180.jpg        11386
# 5459         Thaweesak-SRITHONGDEE-Berry-1586834991.jpg        13663
# 5460  Frederique-LOMBARD-MOREL---VIBRATIONS--1586818...         2100
#
# [5461 rows x 2 columns]

# %%
resized = os.listdir('resized')
print(len(resized))
# Out:
# 5434

# %%
#Selecting all picture in the folder
path_list = []
for p in df['image_name']:
    if p.endswith('jpg'):
        path_list.append(p)
print(len(path_list))
# Out:
# 5461

# %%
#Defining Responses
for pat in path_list:
    new_path = os.path.join('images/',pat) #Path to file
    print(new_path)   #Showing the complete image path
    IMG_SIZE=200
    img_array=cv2.imread(new_path)
    new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
    #plt.imshow(new_array)
    cv2.imwrite('resized/'+pat,new_array)
# Out:
# images/Albert-MARQUET-sans-titre-1560759132.jpg
# images/Diana-KIROVA-Simbiosi-1531216784.jpg
# images/Diana-KIROVA-The-indipendance-day-1519509262.jpg
# images/Edouard-EVENO-Les-clowns-au-cirque--1560517679.jpg
# images/Nathalie-VAREILLE-SORBAC-ENZO-1560675497.jpg
# images/Kiyoshi-HASEGAWA-Oiseau-sur-racine-1557219747.jpg
# images/Therese-BOSC-Passage-rouge-1560584344.jpg
# images/Therese-BOSC-Noces-a-Tipasa--1560584244.jpg
# images/Therese-BOSC-Un-soleil-deja-noye-noircit-peu-a-peu-1560584129.jpg
# images/Therese-BOSC-Je-vis-le-soleil-au-fond-de-la-Mer-1560584020.jpg
# images/Therese-BOSC-A-chaque-vague-une-promesse-1560583919.jpg
# images/Therese-BOSC-Promenade-en-reverie-1560583809.jpg
# images/Therese-BOSC-Coup-de-soleil-sur-la-Falaise-bleue-1560583680.jpg
# images/Dann-AUBERT-Encore-et-encore-1560582547.jpg
# images/Dann-AUBERT-A-la-Lisiere-du-Defini-1560582309.jpg
# images/Dann-AUBERT-La-Vague-d-Or-1560582144.jpg
# images/Dann-AUBERT-Fil-de-Lumiere-1560581920.jpg
# ...

# %%
for i in range(0, len(df['image_price'])):
    df['image_price'][i].strip()

# %%
df.dtypes
# Out:
# image_name     object
# image_price     int64
# dtype: object

# %%
df['image_price'].min()
# Out:
# 1

# %%
os.mkdir('prices')

# %%
for i in range(0,5461):
    folder_name = df['image_price'][i]
    try:
        os.mkdir('prices/'+str(folder_name))
    except:
        pass

# %%
#Sorting Files
image_path = "resized/"

# %%
img_counter=0
try:
    for i in range (1,5461):
        name = df["image_name"][i]
        fname = name
        print(fname)
        finame = df["image_price"][i]
        foname = 'prices/'+str(finame)+'/'+str(fname)
        try:
            os.rename(image_path+fname,foname)
            print('moved for image')
            print('')
            img_counter+=1
        except Exception as e:
            print(e)
except Exception as e:
    print(e)
print(img_counter)
# Out:
# Diana-KIROVA-Simbiosi-1531216784.jpg
# moved for image
#
# Diana-KIROVA-The-indipendance-day-1519509262.jpg
# moved for image
#
# Edouard-EVENO-Les-clowns-au-cirque--1560517679.jpg
# moved for image
#
# Nathalie-VAREILLE-SORBAC-ENZO-1560675497.jpg
# moved for image
#
# Kiyoshi-HASEGAWA-Oiseau-sur-racine-1557219747.jpg
# moved for image
#
# Therese-BOSC-Passage-rouge-1560584344.jpg
# moved for image
#
# Therese-BOSC-Noces-a-Tipasa--1560584244.jpg
# moved for image
#
# Therese-BOSC-Un-soleil-deja-noye-noircit-peu-a-peu-1560584129.jpg
# moved for image
#
# Therese-BOSC-Je-vis-le-soleil-au-fond-de-la-Mer-1560584020.jpg
# moved for image
#
# Therese-BOSC-A-chaque-vague-une-promesse-1560583919.jpg
# moved for image
#
# Therese-BOSC-Promenade-en-reverie-1560583809.jpg
# moved for image
#
# Therese-BOSC-Coup-de-soleil-sur-la-Falaise-bleue-1560583680.jpg
# moved for image
#
# Dann-AUBERT-Encore-et-encore-1560582547.jpg
# moved for image
#
# Dann-AUBERT-A-la-Lisiere-du-Defini-1560582309.jpg
# ...
